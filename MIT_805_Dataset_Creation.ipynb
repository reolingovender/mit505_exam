# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import requests
import xml.etree.ElementTree as ET

url = "https://apps.who.int/gho/athena/api/GHO"
response = requests.get(url, headers={"Accept": "application/xml"})
root = ET.fromstring(response.content)

# %%
import requests
import xml.etree.ElementTree as ET
import pandas as pd

# Function to parse elements and extract Label and Display/text pairs
def parse_label_text_pairs(element):
    data = []

    # Traverse each attribute or dataset-like element and extract Label and Display/text
    for child in element:
        label = child.attrib.get("Label", None)  # Get the 'Label' attribute
        display_text = None

        # Check for 'Display' tag or text content within the child element
        display_element = child.find("Display")
        if display_element is not None:
            display_text = display_element.text
        elif child.text and child.text.strip():
            display_text = child.text.strip()

        if label and display_text:
            data.append({"Label": label, "Display_Text": display_text})

        # Handle nested elements if needed
        data.extend(parse_label_text_pairs(child))

    return data

# Fetch and parse the XML data
try:
    response = requests.get(url, headers={"Accept": "application/xml"})
    if response.status_code != 200:
        print(f"Request failed with status code: {response.status_code}")
    else:
        # Parse the XML content
        root = ET.fromstring(response.content)

        # Parse all 'Label' and 'Display/text' pairs under 'Metadata'
        metadata_data = parse_label_text_pairs(root.find("Metadata"))

        # Convert to DataFrame
        df_measures = pd.DataFrame(metadata_data)


except requests.exceptions.RequestException as e:
    print("Request failed:", e)
except ET.ParseError as e:
    print("Failed to parse XML:", e)

# %%
df_measures
# Out:
#                         Label  \
# 0                    CATEGORY
# 1                 RENDERER_ID
# 2              DEFINITION_XML
# 3                      IMR_ID
# 4                  DISPLAY_FR
# ...                       ...
# 3147  M2_adult_representative
# 3148        M3_adult_periodic
# 3149          M4_youth_recent
# 3150  M5_youth_representative
# 3151        M6_youth_periodic
#
#                                            Display_Text
# 0                                              Category
# 1                                           Renderer ID
# 2                                      Definition (XML)
# 3                                        IMR identifier
# 4                                              Français
# ...                                                 ...
# 3147  Most recent survey among adults was representa...
# 3148  Survey previous to the most recent survey amon...
# 3149  Most recent school-based survey among adolesce...
# 3150  Most recent school-based survey among adolesce...
# 3151  Survey previous to the most recent school-base...
#
# [3152 rows x 2 columns]

# %%
df_measures.to_csv('/content/drive/MyDrive/MIT805_Exam/WHO_HealthData_Meta.csv')

# %%
available_measures = df_measures['Label'][7:].to_list()

# %%
import requests
from io import StringIO
import pandas as pd

key_columns = ['GHO', 'PUBLISHSTATE', 'YEAR', 'REGION', 'COUNTRY', 'Display Value', 'Numeric', 'Low', 'High', 'StdErr', 'StdDev', 'Comments']

# List to store each DataFrame
dataframes = []

for measures in available_measures:
    print(f"Processing measure: {measures}")
    url = "http://apps.who.int/gho/athena/api/GHO/{}.csv".format(measures)
    response = requests.get(url, headers={"Accept": "application/csv"})

    # Check if the response was successful
    if response.status_code == 200 and response.text.strip():  # Ensure response text is not empty
        data = StringIO(response.text)  # Use StringIO to treat text as file-like

        try:
            # Read each CSV into a DataFrame
            df = pd.read_csv(data)

            # Check if DataFrame has non-zero shape
            if df.shape[0] > 0 and df.shape[1] > 0:
                # Check if the 'YEAR' column is missing, and add a default if necessary
                if 'YEAR' not in df.columns:
                    df['YEAR'] = 'Unknown'  # or set it to a specific year if appropriate

                # Reshape the DataFrame
                df = pd.melt(df, id_vars=[col for col in key_columns if col in df.columns],
                             var_name="attribute", value_name="value")

                # Append the reshaped DataFrame to the list
                dataframes.append(df)
            else:
                print(f"Discarded empty DataFrame for measure: {measures}")
        except pd.errors.EmptyDataError:
            print(f"No data to parse for measure: {measures}")
    else:
        print(f"Failed to retrieve data for measure: {measures} with status code: {response.status_code}")

# Concatenate all DataFrames in the list into a single DataFrame
if dataframes:
    final_df = pd.concat(dataframes, ignore_index=True)
    # Display the concatenated DataFrame
    print(final_df.head())
else:
    print("No valid DataFrames to concatenate.")
# Out:
# Processing measure: MDG_0000000001
# Processing measure: MDG_0000000003
# Processing measure: MDG_0000000005
# Discarded empty DataFrame for measure: MDG_0000000005
# Processing measure: MDG_0000000007
# Processing measure: MDG_0000000010
# Processing measure: MDG_0000000011
# Processing measure: MDG_0000000013
# Discarded empty DataFrame for measure: MDG_0000000013
# Processing measure: MDG_0000000014
# Discarded empty DataFrame for measure: MDG_0000000014
# Processing measure: MDG_0000000015
# Processing measure: MDG_0000000016
# Discarded empty DataFrame for measure: MDG_0000000016
# Processing measure: MDG_0000000017
# Processing measure: MDG_0000000018
# Discarded empty DataFrame for measure: MDG_0000000018
# Processing measure: MDG_0000000019
# Discarded empty DataFrame for measure: MDG_0000000019
# Processing measure: MDG_0000000020
# Processing measure: MDG_0000000021
# Processing measure: MDG_0000000022
# Discarded empty DataFrame for measure: MDG_0000000022
# Processing measure: MDG_0000000023
# Discarded empty DataFrame for measure: MDG_0000000023
# Processing measure: MDG_0000000024
# Discarded empty DataFrame for measure: MDG_0000000024
# Processing measure: MDG_0000000025
# Processing measure: MDG_0000000026
# Processing measure: MDG_0000000027
# Discarded empty DataFrame for measure: MDG_0000000027
# Processing measure: LIFE_0000000029
# Processing measure: LIFE_0000000030
# Processing measure: LIFE_0000000031
# Processing measure: LIFE_0000000032
# Processing measure: LIFE_0000000033
# Processing measure: LIFE_0000000034
# Processing measure: LIFE_0000000035
# Processing measure: GBD_0000000036
# Discarded empty DataFrame for measure: GBD_0000000036
# Processing measure: GBD_0000000038
# Discarded empty DataFrame for measure: GBD_0000000038
# Processing measure: WHS3_40
# Discarded empty DataFrame for measure: WHS3_40
# Processing measure: WHS3_41
# Processing measure: WHS3_42
# Processing measure: WHS3_43
# Processing measure: WHS3_45
# Processing measure: WHS3_46
# Processing measure: WHS3_47
# Discarded empty DataFrame for measure: WHS3_47
# Processing measure: WHS3_48
# Discarded empty DataFrame for measure: WHS3_48
# Processing measure: WHS3_49
# Processing measure: WHS3_50
# Processing measure: WHS3_51
# Discarded empty DataFrame for measure: WHS3_51
# Processing measure: WHS3_52
# Discarded empty DataFrame for measure: WHS3_52
# Processing measure: WHS3_53
# Processing measure: WHS3_54
# Discarded empty DataFrame for measure: WHS3_54
# Processing measure: WHS3_55
# Processing measure: WHS3_56
# Processing measure: WHS3_57
# Processing measure: WHS3_62
# Processing measure: WHOSIS_000001
# Processing measure: WHOSIS_000002
# Processing measure: WHOSIS_000003
# Processing measure: WHOSIS_000004
# Processing measure: WHOSIS_000005
# Discarded empty DataFrame for measure: WHOSIS_000005
# Processing measure: WHOSIS_000006
# Processing measure: WHOSIS_000008
# Discarded empty DataFrame for measure: WHOSIS_000008
# Processing measure: WHOSIS_000013
# Discarded empty DataFrame for measure: WHOSIS_000013
# Processing measure: WHOSIS_000009
# Discarded empty DataFrame for measure: WHOSIS_000009
# Processing measure: WHOSIS_000010
# Discarded empty DataFrame for measure: WHOSIS_000010
# Processing measure: WHOSIS_000012
# Discarded empty DataFrame for measure: WHOSIS_000012
# Processing measure: WHS9_85
# Discarded empty DataFrame for measure: WHS9_85
# Processing measure: WHS9_86
# Discarded empty DataFrame for measure: WHS9_86
# Processing measure: WHS9_87
# Discarded empty DataFrame for measure: WHS9_87
# Processing measure: WHS9_88
# Discarded empty DataFrame for measure: WHS9_88
# Processing measure: WHS9_89
# Discarded empty DataFrame for measure: WHS9_89
# Processing measure: WHS9_90
# Discarded empty DataFrame for measure: WHS9_90
# Processing measure: WHS9_91
# Discarded empty DataFrame for measure: WHS9_91
# Processing measure: WHS9_92
# Discarded empty DataFrame for measure: WHS9_92
# Processing measure: WHS9_93
# Discarded empty DataFrame for measure: WHS9_93
# Processing measure: WHS9_94
# Discarded empty DataFrame for measure: WHS9_94
# Processing measure: WHS9_95
# Discarded empty DataFrame for measure: WHS9_95
# Processing measure: WHS9_96
# Discarded empty DataFrame for measure: WHS9_96
# Processing measure: WHS9_97
# Discarded empty DataFrame for measure: WHS9_97
# Processing measure: WHS4_99
# Discarded empty DataFrame for measure: WHS4_99
# Processing measure: WHS4_100
# Processing measure: WHS6_101
# Processing measure: WHS6_102
# Processing measure: WHS7_103
# Discarded empty DataFrame for measure: WHS7_103
# Processing measure: WHS7_104
# Discarded empty DataFrame for measure: WHS7_104
# Processing measure: WHS7_105
# Discarded empty DataFrame for measure: WHS7_105
# Processing measure: WHS4_106
# Processing measure: WHS4_107
# Discarded empty DataFrame for measure: WHS4_107
# Processing measure: WHS7_108
# Discarded empty DataFrame for measure: WHS7_108
# Processing measure: WHS8_110
# Processing measure: WHS4_111
# Processing measure: WHS7_113
# Discarded empty DataFrame for measure: WHS7_113
# Processing measure: WHS4_115
# Processing measure: WHS6_116
# Processing measure: WHS4_117
# Processing measure: WHS7_120
# Discarded empty DataFrame for measure: WHS7_120
# Processing measure: WHS6_123
# Discarded empty DataFrame for measure: WHS6_123
# Processing measure: WHS4_124
# Discarded empty DataFrame for measure: WHS4_124
# Processing measure: WHS2_126
# Processing measure: WHS6_127
# Discarded empty DataFrame for measure: WHS6_127
# Processing measure: WHS4_128
# Processing measure: WHS4_129
# Processing measure: WHS2_131
# Processing measure: WHS7_134
# Discarded empty DataFrame for measure: WHS7_134
# Processing measure: WHS2_138
# Processing measure: WHS7_139
# Discarded empty DataFrame for measure: WHS7_139
# Processing measure: WHS6_140
# Discarded empty DataFrame for measure: WHS6_140
# Processing measure: WHS7_143
# Discarded empty DataFrame for measure: WHS7_143
# Processing measure: WHS6_144
# Discarded empty DataFrame for measure: WHS6_144
# Processing measure: WHS7_147
# Discarded empty DataFrame for measure: WHS7_147
# Processing measure: WHS6_148
# Discarded empty DataFrame for measure: WHS6_148
# Processing measure: WHS7_149
# Discarded empty DataFrame for measure: WHS7_149
# Processing measure: WHS6_150
# Discarded empty DataFrame for measure: WHS6_150
# Processing measure: WHS2_152
# Processing measure: WHS4_154
# Processing measure: WHS7_156
# Discarded empty DataFrame for measure: WHS7_156
# Processing measure: WHS2_160
# Processing measure: WHS2_161
# Processing measure: WHS2_164
# Discarded empty DataFrame for measure: WHS2_164
# Processing measure: WHS2_165
# Discarded empty DataFrame for measure: WHS2_165
# Processing measure: WHS2_166
# Discarded empty DataFrame for measure: WHS2_166
# Processing measure: WHS2_167
# Discarded empty DataFrame for measure: WHS2_167
# Processing measure: WHS2_168
# Discarded empty DataFrame for measure: WHS2_168
# Processing measure: WHS2_170
# Discarded empty DataFrame for measure: WHS2_170
# Processing measure: WHS2_171
# Discarded empty DataFrame for measure: WHS2_171
# Processing measure: WHS2_174
# Processing measure: ODA_1
# Processing measure: ODA_2
# Processing measure: ODA_3
# Processing measure: ODA_4
# Processing measure: GBD_DALYRTAGE
# Processing measure: TOBACCO_0000000192
# Discarded empty DataFrame for measure: TOBACCO_0000000192
# Processing measure: TOBACCO_0000000209
# Discarded empty DataFrame for measure: TOBACCO_0000000209
# Processing measure: TOBACCO_0000000210
# Discarded empty DataFrame for measure: TOBACCO_0000000210
# Processing measure: TOBACCO_0000000211
# Discarded empty DataFrame for measure: TOBACCO_0000000211
# Processing measure: TOBACCO_0000000212
# Discarded empty DataFrame for measure: TOBACCO_0000000212
# Processing measure: TOBACCO_0000000213
# Discarded empty DataFrame for measure: TOBACCO_0000000213
# Processing measure: CHOLERA_0000000001
# Processing measure: CHOLERA_0000000002
# Processing measure: CHOLERA_0000000003
# Processing measure: TOBACCO_0000000342
# Discarded empty DataFrame for measure: TOBACCO_0000000342
# Processing measure: TOBACCO_0000000344
# Discarded empty DataFrame for measure: TOBACCO_0000000344
# Processing measure: TOBACCO_0000000345
# Discarded empty DataFrame for measure: TOBACCO_0000000345
# Processing measure: TOBACCO_0000000346
# Discarded empty DataFrame for measure: TOBACCO_0000000346
# Processing measure: TOBACCO_0000000347
# Discarded empty DataFrame for measure: TOBACCO_0000000347
# Processing measure: TOBACCO_0000000361
# Discarded empty DataFrame for measure: TOBACCO_0000000361
# Processing measure: TOBACCO_0000000362
# Discarded empty DataFrame for measure: TOBACCO_0000000362
# Processing measure: TOBACCO_0000000363
# Discarded empty DataFrame for measure: TOBACCO_0000000363
# Processing measure: TOBACCO_0000000364
# Discarded empty DataFrame for measure: TOBACCO_0000000364
# Processing measure: TOBACCO_0000000365
# Discarded empty DataFrame for measure: TOBACCO_0000000365
# Processing measure: TOBACCO_0000000366
# Discarded empty DataFrame for measure: TOBACCO_0000000366
# Processing measure: TOBACCO_0000000367
# Discarded empty DataFrame for measure: TOBACCO_0000000367
# Processing measure: TOBACCO_0000000368
# Discarded empty DataFrame for measure: TOBACCO_0000000368
# Processing measure: TOBACCO_0000000369
# Discarded empty DataFrame for measure: TOBACCO_0000000369
# Processing measure: TOBACCO_0000000370
# Discarded empty DataFrame for measure: TOBACCO_0000000370
# Processing measure: TOBACCO_0000000371
# Discarded empty DataFrame for measure: TOBACCO_0000000371
# Processing measure: TOBACCO_0000000372
# Discarded empty DataFrame for measure: TOBACCO_0000000372
# Processing measure: TOBACCO_0000000386
# Discarded empty DataFrame for measure: TOBACCO_0000000386
# Processing measure: TOBACCO_0000000387
# Discarded empty DataFrame for measure: TOBACCO_0000000387
# Processing measure: TOBACCO_0000000388
# Discarded empty DataFrame for measure: TOBACCO_0000000388
# Processing measure: TOBACCO_0000000389
# Discarded empty DataFrame for measure: TOBACCO_0000000389
# Processing measure: TOBACCO_0000000390
# Discarded empty DataFrame for measure: TOBACCO_0000000390
# Processing measure: TOBACCO_0000000391
# Discarded empty DataFrame for measure: TOBACCO_0000000391
# Processing measure: TOBACCO_0000000392
# Discarded empty DataFrame for measure: TOBACCO_0000000392
# Processing measure: TOBACCO_0000000393
# Discarded empty DataFrame for measure: TOBACCO_0000000393
# Processing measure: TOBACCO_0000000394
# Discarded empty DataFrame for measure: TOBACCO_0000000394
# Processing measure: TOBACCO_0000000395
# Discarded empty DataFrame for measure: TOBACCO_0000000395
# Processing measure: TOBACCO_0000000396
# Discarded empty DataFrame for measure: TOBACCO_0000000396
# Processing measure: RS_193
# Processing measure: RS_194
# Processing measure: RS_196
# Processing measure: RS_198
# Processing measure: RS_204
# Processing measure: RS_208
# Processing measure: RS_209
# Processing measure: RS_210
# Processing measure: RS_213
# Processing measure: RS_214
# Processing measure: RS_225
# Processing measure: RS_228
# Processing measure: RS_229
# Processing measure: RS_237
# Processing measure: RS_205
# Processing measure: RS_246
# Processing measure: RS_207
# Processing measure: RS_212
# Processing measure: RS_219
# Processing measure: RS_238
# Processing measure: RS_217
# Processing measure: RS_576
# Processing measure: MDG_0000000029
# Processing measure: TOBACCO_0000000505
# Discarded empty DataFrame for measure: TOBACCO_0000000505
# Processing measure: TOBACCO_0000000506
# Discarded empty DataFrame for measure: TOBACCO_0000000506
# Processing measure: TOBACCO_0000000507
# Discarded empty DataFrame for measure: TOBACCO_0000000507
# Processing measure: MDG_0000000030
# Processing measure: MDG_0000000031
# Processing measure: WHS5_512
# Processing measure: WHS2_514
# Discarded empty DataFrame for measure: WHS2_514
# Processing measure: WHS2_515
# Discarded empty DataFrame for measure: WHS2_515
# Processing measure: WHS2_516
# Discarded empty DataFrame for measure: WHS2_516
# Processing measure: WHS6_517
# Discarded empty DataFrame for measure: WHS6_517
# Processing measure: WHS6_518
# Discarded empty DataFrame for measure: WHS6_518
# Processing measure: WHS6_519
# Discarded empty DataFrame for measure: WHS6_519
# Processing measure: WHS6_520
# Discarded empty DataFrame for measure: WHS6_520
# Processing measure: MDG_0000000032
# Processing measure: WHS3_522
# Processing measure: WHS2_523
# Discarded empty DataFrame for measure: WHS2_523
# Processing measure: NUTRITION_564
# Processing measure: NUTRITION_570
# Processing measure: NUTRITION_579
# Processing measure: WHS4_543
# Processing measure: WHS4_544
# Processing measure: SA_0000001398
# Processing measure: SA_0000001400
# Processing measure: SA_0000001401
# Processing measure: SA_0000001402
# Processing measure: SA_0000001403
# Processing measure: SA_0000001404
# Processing measure: SA_0000001405
# Processing measure: SA_0000001406
# Failed to retrieve data for measure: SA_0000001406 with status code: 502
# Processing measure: MDG_0000000033
# Processing measure: MDG_0000000034
# Processing measure: SA_0000001409
# Processing measure: SA_0000001410
# Processing measure: SA_0000001411
# Processing measure: SA_0000001412
# Processing measure: SA_0000001413
# Processing measure: SA_0000001414
# Processing measure: SA_0000001416
# Processing measure: SA_0000001417
# Processing measure: SA_0000001418
# Processing measure: SA_0000001419
# Processing measure: SA_0000001420
# Processing measure: SA_0000001421
# Processing measure: SA_0000001422
# Processing measure: SA_0000001423
# Processing measure: SA_0000001424
# Processing measure: SA_0000001425
# Processing measure: SA_0000001426
# Processing measure: SA_0000001427
# Processing measure: SA_0000001429
# Processing measure: SA_0000001430
# Processing measure: SA_0000001431
# Processing measure: SA_0000001432
# Processing measure: SA_0000001433
# Processing measure: SA_0000001434
# Processing measure: SA_0000001435
# Processing measure: SA_0000001436
# Processing measure: SA_0000001437
# Processing measure: SA_0000001438
# Processing measure: SA_0000001439
# Processing measure: SA_0000001440
# Processing measure: SA_0000001441
# Processing measure: SA_0000001442
# Processing measure: SA_0000001443
# Processing measure: SA_0000001444
# Processing measure: SA_0000001445
# Processing measure: SA_0000001446
# Processing measure: SA_0000001448
# Processing measure: SA_0000001449
# Processing measure: SA_0000001450
# Processing measure: SA_0000001451
# Processing measure: SA_0000001452
# Processing measure: SA_0000001453
# Processing measure: SA_0000001454
# Processing measure: SA_0000001455
# Processing measure: SA_0000001456
# Processing measure: SA_0000001457
# Processing measure: SA_0000001458
# Processing measure: SA_0000001459
# Processing measure: SA_0000001460
# Processing measure: SA_0000001461
# Processing measure: SA_0000001462
# Processing measure: SA_0000001463
# Processing measure: SA_0000001464
# Processing measure: SA_0000001465
# Processing measure: SA_0000001466
# Processing measure: SA_0000001467
# Processing measure: SA_0000001468
# Processing measure: SA_0000001469
# Processing measure: SA_0000001470
# Processing measure: SA_0000001471
# Processing measure: SA_0000001472
# Processing measure: SA_0000001473
# Processing measure: SA_0000001474
# Processing measure: SA_0000001475
# Processing measure: SA_0000001476
# Processing measure: SA_0000001477
# Processing measure: HIV_0000000001
# Processing measure: HIV_0000000002
# Discarded empty DataFrame for measure: HIV_0000000002
# Processing measure: HIV_0000000006
# Processing measure: HIV_0000000007
# Processing measure: HIV_0000000008
# Processing measure: HIV_0000000009
# Processing measure: HIV_0000000011
# Processing measure: HIV_0000000012
# Processing measure: HIV_0000000015
# Processing measure: HIV_0000000016
# Discarded empty DataFrame for measure: HIV_0000000016
# Processing measure: HIV_0000000020
# Processing measure: HIV_0000000021
# Processing measure: HIV_0000000022
# Processing measure: HIV_0000000023
# Processing measure: HIV_0000000024
# Processing measure: SA_0000001502
# Processing measure: SA_0000001503
# Processing measure: SA_0000001504
# Processing measure: SA_0000001506
# Processing measure: LEAD_1
# Processing measure: LEAD_2
# Processing measure: LEAD_3
# Processing measure: LEAD_4
# Processing measure: LEAD_5
# Processing measure: LEAD_6
# Processing measure: LEAD_7
# Processing measure: LEAD_8
# Processing measure: LEAD_9
# Processing measure: LEAD_10
# Processing measure: SHS_1
# Processing measure: SHS_2
# Processing measure: SHS_3
# Processing measure: SHS_4
# Processing measure: SHS_5
# Processing measure: SHS_6
# Processing measure: SHS_7
# Processing measure: SHS_8
# Processing measure: SHS_9
# Processing measure: SHS_10
# Processing measure: SHS_11
# Processing measure: WSH_1
# Processing measure: WSH_2
# Processing measure: WSH_3
# Processing measure: WSH_4
# Processing measure: WSH_5
# Processing measure: WSH_6
# Processing measure: WSH_7
# Processing measure: WSH_8
# Processing measure: AIR_1
# Discarded empty DataFrame for measure: AIR_1
# Processing measure: AIR_2
# Discarded empty DataFrame for measure: AIR_2
# Processing measure: AIR_3
# Discarded empty DataFrame for measure: AIR_3
# Processing measure: AIR_4
# Processing measure: AIR_5
# Processing measure: AIR_6
# Processing measure: AIR_7
# Processing measure: AIR_8
# Processing measure: AIR_9
# Processing measure: AIR_10
# Processing measure: AIR_11
# Processing measure: AIR_12
# Processing measure: AIR_13
# Discarded empty DataFrame for measure: AIR_13
# Processing measure: AIR_14
# Discarded empty DataFrame for measure: AIR_14
# Processing measure: AIR_15
# Processing measure: AIR_16
# Processing measure: AIR_17
# Processing measure: AIR_18
# Discarded empty DataFrame for measure: AIR_18
# Processing measure: TB_1
# Processing measure: MENING_1
# Processing measure: MENING_2
# Processing measure: TB_e_mort_exc_tbhiv_num
# Processing measure: TB_e_prev_num
# Processing measure: TB_e_inc_num
# Processing measure: TB_e_inc_tbhiv_100k
# Processing measure: TB_e_inc_tbhiv_num
# Processing measure: AIR_24
# Discarded empty DataFrame for measure: AIR_24
# Processing measure: AIR_30
# Discarded empty DataFrame for measure: AIR_30
# Processing measure: TB_tot_newrel
# Processing measure: SA_0000001507
# Processing measure: SA_0000001508
# Processing measure: SA_0000001509
# Processing measure: SA_0000001510
# Processing measure: SA_0000001511
# Processing measure: SA_0000001512
# Processing measure: SA_0000001513
# Processing measure: SA_0000001514
# Processing measure: SA_0000001515
# Processing measure: SA_0000001516
# Processing measure: SA_0000001517
# Processing measure: SA_0000001518
# Processing measure: SA_0000001519
# Processing measure: SA_0000001520
# Processing measure: SA_0000001521
# Processing measure: SA_0000001523
# Processing measure: SA_0000001525
# Processing measure: SA_0000001526
# Processing measure: SA_0000001527
# Processing measure: SA_0000001528
# Processing measure: SA_0000001529
# Processing measure: SA_0000001530
# Processing measure: SA_0000001531
# Processing measure: SA_0000001532
# Processing measure: SA_0000001533
# Processing measure: SA_0000001534
# Processing measure: SA_0000001535
# Processing measure: SA_0000001536
# Processing measure: SA_0000001537
# Processing measure: SA_0000001538
# Processing measure: SA_0000001539
# Processing measure: SA_0000001540
# Processing measure: SA_0000001541
# Processing measure: SA_0000001542
# Processing measure: SA_0000001543
# Processing measure: SA_0000001544
# Processing measure: SA_0000001545
# Processing measure: SA_0000001546
# Processing measure: SA_0000001547
# Processing measure: SA_0000001548
# Processing measure: SA_0000001549
# Processing measure: SA_0000001550
# Failed to retrieve data for measure: SA_0000001550 with status code: 502
# Processing measure: SA_0000001551
# Processing measure: SA_0000001553
# Processing measure: SA_0000001554
# Processing measure: SA_0000001555
# Processing measure: SA_0000001651
# Processing measure: SA_0000001653
# Processing measure: SA_0000001652
# Processing measure: SA_0000001647
# Processing measure: SA_0000001648
# Processing measure: SA_0000001650
# Processing measure: SA_0000001649
# Processing measure: SA_0000001676
# Processing measure: SA_0000001677
# Processing measure: SA_0000001678
# Processing measure: SA_0000001679
# Processing measure: SA_0000001680
# Processing measure: SA_0000001681
# Processing measure: SA_0000001682
# Processing measure: SA_0000001683
# Processing measure: SA_0000001654
# Processing measure: SA_0000001655
# Processing measure: SA_0000001684
# Processing measure: SA_0000001685
# Processing measure: SA_0000001686
# Processing measure: SA_0000001687
# Processing measure: TB_new_sp
# Processing measure: TB_new_sn
# Processing measure: TB_new_su
# Processing measure: TB_new_ep
# Processing measure: TB_new_oth
# Processing measure: TB_ret_rel
# Processing measure: TB_ret_taf
# Processing measure: TB_ret_tad
# Processing measure: TB_ret_oth
# Processing measure: TB_newret_oth
# Processing measure: MORT_100
# Failed to retrieve data for measure: MORT_100 with status code: 502
# Processing measure: MORT_200
# Failed to retrieve data for measure: MORT_200 with status code: 500
# Processing measure: MORT_300
# Failed to retrieve data for measure: MORT_300 with status code: 500
# Processing measure: TB_c_lab_sm_100k
# Processing measure: TB_c_lab_cul_5m
# Processing measure: TB_c_lab_dst_5m
# Processing measure: TB_sldst_avail
# Processing measure: TB_c_new_snep_tsr
# Processing measure: TB_c_ret_tsr
# Processing measure: NCD_BMI_25A
# Processing measure: NCD_BMI_25C
# Processing measure: NCD_BMI_30A
# Processing measure: NCD_BMI_30C
# Failed to retrieve data for measure: NCD_BMI_30C with status code: 200
# Processing measure: NCD_BMI_MEAN
# Failed to retrieve data for measure: NCD_BMI_MEAN with status code: 502
# Processing measure: NCD_PAA
# Processing measure: NCD_PAC
# Processing measure: CC_1
# Processing measure: CC_2
# Processing measure: CC_3
# Processing measure: CC_4
# Processing measure: CC_5
# Processing measure: CC_6
# Processing measure: CC_7
# Processing measure: CC_8
# Processing measure: OCC_1
# Processing measure: OCC_2
# Processing measure: OCC_3
# Processing measure: OCC_4
# Processing measure: TOTENV_1
# Processing measure: TOTENV_2
# Processing measure: TOTENV_3
# Processing measure: TOTENV_4
# Processing measure: TOTENV_5
# Processing measure: TOTENV_6
# Processing measure: TOTENV_7
# Processing measure: TOTENV_8
# Processing measure: TOTENV_9
# Processing measure: TOTENV_10
# Processing measure: TOTENV_11
# Processing measure: TOTENV_12
# Processing measure: UV_1
# Processing measure: UV_2
# Processing measure: UV_3
# Processing measure: UV_4
# Processing measure: UV_5
# Processing measure: NCD_CCS_CVDPlan
# Processing measure: NCD_CCS_CancerPlan
# Processing measure: NCD_CCS_DiabPlan
# Processing measure: NCD_CCS_CRDPlan
# Processing measure: NCD_CCS_AlcPlan
# Processing measure: NCD_CCS_DietPlan
# Processing measure: NCD_CCS_PAPlan
# Processing measure: NCD_CCS_TobPlan
# Processing measure: NCD_CCS_CervCy
# Processing measure: NCD_CCS_BowelCancer
# Processing measure: NCD_CCS_BreastCancer
# Processing measure: NCD_CCS_DiabetesTest
# Processing measure: NCD_CCS_CholMsmt
# Processing measure: NCD_CCS_Spirom
# Processing measure: NCD_CCS_Insulin
# Processing measure: NCD_CCS_Aspirin
# Processing measure: NCD_CCS_Metformin
# Processing measure: NCD_CCS_Thiazide
# Processing measure: NCD_CCS_ACE
# Processing measure: NCD_CCS_CCBlkrs
# Processing measure: NCD_CCS_Statins
# Processing measure: NCD_CCS_OralMorph
# Processing measure: NCD_CCS_Nicotine
# Processing measure: NCD_CCS_Steroid
# Processing measure: OCC_5
# Processing measure: OCC_6
# Processing measure: OCC_7
# Processing measure: OCC_8
# Processing measure: OCC_9
# Processing measure: OCC_10
# Processing measure: OCC_11
# Processing measure: OCC_12
# Processing measure: OCC_13
# Processing measure: OCC_14
# Processing measure: OCC_15
# Processing measure: OCC_16
# Processing measure: OCC_17
# Processing measure: OCC_18
# Processing measure: OCC_19
# Processing measure: OCC_20
# Processing measure: OCC_21
# Processing measure: OCC_22
# Processing measure: HRH_01
# Discarded empty DataFrame for measure: HRH_01
# Processing measure: HRH_02
# Discarded empty DataFrame for measure: HRH_02
# Processing measure: HRH_03
# Discarded empty DataFrame for measure: HRH_03
# Processing measure: HRH_04
# Discarded empty DataFrame for measure: HRH_04
# Processing measure: HRH_05
# Discarded empty DataFrame for measure: HRH_05
# Processing measure: HRH_06
# Discarded empty DataFrame for measure: HRH_06
# Processing measure: HRH_07
# Discarded empty DataFrame for measure: HRH_07
# Processing measure: HRH_08
# Discarded empty DataFrame for measure: HRH_08
# Processing measure: HRH_09
# Discarded empty DataFrame for measure: HRH_09
# Processing measure: HRH_10
# Discarded empty DataFrame for measure: HRH_10
# Processing measure: HRH_11
# Discarded empty DataFrame for measure: HRH_11
# Processing measure: HRH_12
# Discarded empty DataFrame for measure: HRH_12
# Processing measure: HRH_13
# Discarded empty DataFrame for measure: HRH_13
# Processing measure: HRH_14
# Discarded empty DataFrame for measure: HRH_14
# Processing measure: HRH_15
# Discarded empty DataFrame for measure: HRH_15
# Processing measure: HRH_16
# Discarded empty DataFrame for measure: HRH_16
# Processing measure: HRH_17
# Discarded empty DataFrame for measure: HRH_17
# Processing measure: HRH_18
# Discarded empty DataFrame for measure: HRH_18
# Processing measure: HRH_19
# Discarded empty DataFrame for measure: HRH_19
# Processing measure: HRH_20
# Discarded empty DataFrame for measure: HRH_20
# Processing measure: HRH_21
# Discarded empty DataFrame for measure: HRH_21
# Processing measure: HRH_22
# Discarded empty DataFrame for measure: HRH_22
# Processing measure: HRH_23
# Discarded empty DataFrame for measure: HRH_23
# Processing measure: HRH_24
# Discarded empty DataFrame for measure: HRH_24
# Processing measure: HRH_25
# Discarded empty DataFrame for measure: HRH_25
# Processing measure: HRH_26
# Discarded empty DataFrame for measure: HRH_26
# Processing measure: HRH_27
# Discarded empty DataFrame for measure: HRH_27
# Processing measure: HRH_28
# Discarded empty DataFrame for measure: HRH_28
# Processing measure: HRH_29
# Discarded empty DataFrame for measure: HRH_29
# Processing measure: HRH_30
# Discarded empty DataFrame for measure: HRH_30
# Processing measure: HRH_31
# Discarded empty DataFrame for measure: HRH_31
# Processing measure: HRH_32
# Discarded empty DataFrame for measure: HRH_32
# Processing measure: HRH_33
# Discarded empty DataFrame for measure: HRH_33
# Processing measure: BP_03
# Processing measure: BP_04
# Processing measure: BP_05
# Processing measure: BP_06
# Processing measure: RS_1845
# Processing measure: NCD_DTH_TOT
# Processing measure: NCD_UNDER70
# Processing measure: WHOSIS_000014
# Processing measure: NCD_GLUC_01
# Processing measure: NCD_GLUC_02
# Processing measure: NCD_GLUC_03
# Processing measure: NCD_GLUC_04
# Processing measure: WHS6_100
# Processing measure: NCD_BMI_MEANC
# Failed to retrieve data for measure: NCD_BMI_MEANC with status code: 502
# Processing measure: NTD_1
# Processing measure: NTD_2
# Discarded empty DataFrame for measure: NTD_2
# Processing measure: NTD_3
# Discarded empty DataFrame for measure: NTD_3
# Processing measure: NTD_4
# Processing measure: NTD_5
# Processing measure: NTD_6
# Processing measure: NTD_7
# Processing measure: NTD_8
# Processing measure: MENING_3
# Processing measure: SA_0000001688
# Processing measure: MDG_0000000005_AGE1519
# Discarded empty DataFrame for measure: MDG_0000000005_AGE1519
# Processing measure: MDG_0000000006_AGE1519
# Discarded empty DataFrame for measure: MDG_0000000006_AGE1519
# Processing measure: MDG_0000000025_AGE1519
# Discarded empty DataFrame for measure: MDG_0000000025_AGE1519
# Processing measure: WHS4_111_AGE1519
# Processing measure: HWWS_2
# Processing measure: HWWS_1
# Processing measure: RSUD_1
# Processing measure: RSUD_2
# Processing measure: RSUD_3
# Processing measure: RSUD_5
# Processing measure: RSUD_7
# Processing measure: SA_0000001689
# Processing measure: SA_0000001690
# Processing measure: RSUD_8
# Processing measure: RSUD_9
# Processing measure: RSUD_10
# Processing measure: RSUD_11
# Processing measure: RSUD_12
# Processing measure: RSUD_13
# Processing measure: RSUD_14
# Processing measure: RSUD_15
# Processing measure: RSUD_16
# Processing measure: RSUD_17
# Processing measure: RSUD_18
# Processing measure: RSUD_19
# Processing measure: RSUD_20
# Processing measure: RSUD_21
# Processing measure: RSUD_22
# Processing measure: RSUD_23
# Processing measure: RSUD_26
# Processing measure: RSUD_27
# Processing measure: RSUD_28
# Processing measure: RSUD_29
# Processing measure: RSUD_30
# Processing measure: RSUD_31
# Processing measure: RSUD_32
# Processing measure: RSUD_33
# Processing measure: RSUD_34
# Processing measure: RSUD_35
# Processing measure: RSUD_36
# Processing measure: RSUD_37
# Processing measure: RSUD_38
# Processing measure: RSUD_39
# Processing measure: RSUD_40
# Processing measure: AIR_2_1
# Discarded empty DataFrame for measure: AIR_2_1
# Processing measure: AIR_3_1
# Discarded empty DataFrame for measure: AIR_3_1
# Processing measure: RSUD_41
# Processing measure: RSUD_42
# Processing measure: RSUD_43
# Processing measure: RSUD_44
# Processing measure: RSUD_45
# Processing measure: RSUD_46
# Processing measure: RSUD_47
# Processing measure: RSUD_48
# Processing measure: CM_01
# Processing measure: CM_02
# Processing measure: CM_03
# Processing measure: RSUD_49
# Processing measure: RSUD_50
# Processing measure: RSUD_51
# Processing measure: RSUD_52
# Processing measure: RSUD_53
# Processing measure: RSUD_54
# Processing measure: RSUD_55
# Processing measure: RSUD_56
# Processing measure: RSUD_57
# Processing measure: RSUD_58
# Processing measure: RSUD_59
# Processing measure: RSUD_60
# Processing measure: RSUD_61
# Processing measure: RSUD_62
# Processing measure: RSUD_63
# Processing measure: RSUD_64
# Processing measure: RSUD_65
# Processing measure: RSUD_66
# Processing measure: RSUD_67
# Processing measure: RSUD_68
# Processing measure: RSUD_69
# Processing measure: RSUD_70
# Processing measure: RSUD_71
# Processing measure: RSUD_72
# Processing measure: NUTRITION_2005
# Processing measure: RSUD_73
# Processing measure: RSUD_74
# Processing measure: RSUD_75
# Processing measure: RSUD_76
# Processing measure: RSUD_77
# Processing measure: RSUD_78
# Processing measure: RSUD_79
# Processing measure: RSUD_80
# Processing measure: RSUD_81
# Processing measure: RSUD_82
# Processing measure: RSUD_83
# Processing measure: RSUD_84
# Processing measure: RSUD_85
# Processing measure: RSUD_86
# Processing measure: RSUD_87
# Processing measure: RSUD_88
# Processing measure: MH_1
# Processing measure: MH_2
# Processing measure: MH_3
# Processing measure: MH_4
# Processing measure: MH_5
# Processing measure: MH_6
# Processing measure: MH_7
# Processing measure: MH_8
# Processing measure: MH_9
# Processing measure: MH_10
# Processing measure: MH_11
# Processing measure: MH_12
# Processing measure: MH_13
# Processing measure: MH_14
# Processing measure: MH_15
# Processing measure: MH_16
# Processing measure: RSUD_89
# Processing measure: MH_17
# Processing measure: MH_18
# Processing measure: WHS4_108
# Discarded empty DataFrame for measure: WHS4_108
# Processing measure: WHOSIS_000015
# Processing measure: MALARIA001
# Discarded empty DataFrame for measure: MALARIA001
# Processing measure: MALARIA002
# Discarded empty DataFrame for measure: MALARIA002
# Processing measure: MALARIA003
# Discarded empty DataFrame for measure: MALARIA003
# Processing measure: DEVICES01
# Processing measure: DEVICES02
# Processing measure: DEVICES03
# Processing measure: DEVICES04
# Processing measure: DEVICES05
# Processing measure: DEVICES06
# Processing measure: DEVICES07
# Processing measure: DEVICES08
# Processing measure: DEVICES09
# Processing measure: DEVICES10
# Processing measure: DEVICES11
# Processing measure: DEVICES12
# Processing measure: DEVICES13
# Processing measure: DEVICES14
# Processing measure: DEVICES15
# Processing measure: DEVICES16
# Processing measure: DEVICES17
# Processing measure: DEVICES18
# Processing measure: DEVICES19
# Processing measure: DEVICES20
# Processing measure: DEVICES21
# Processing measure: DEVICES22
# Processing measure: DEVICES23
# Processing measure: SA_0000001691
# Processing measure: SA_0000001692
# Processing measure: SA_0000001693
# Processing measure: SA_0000001694
# Processing measure: SA_0000001695
# Processing measure: SA_0000001696
# Processing measure: WHS9_CS
# Discarded empty DataFrame for measure: WHS9_CS
# Processing measure: WHS10_1
# Discarded empty DataFrame for measure: WHS10_1
# Processing measure: WHS10_2
# Discarded empty DataFrame for measure: WHS10_2
# Processing measure: WHS10_3
# Discarded empty DataFrame for measure: WHS10_3
# Processing measure: WHS10_4
# Discarded empty DataFrame for measure: WHS10_4
# Processing measure: WHS10_5
# Discarded empty DataFrame for measure: WHS10_5
# Processing measure: WHS10_6
# Discarded empty DataFrame for measure: WHS10_6
# Processing measure: WHS10_7
# Discarded empty DataFrame for measure: WHS10_7
# Processing measure: WHS10_8
# Processing measure: WHS10_9
# Processing measure: WHS10_10
# Discarded empty DataFrame for measure: WHS10_10
# Processing measure: HIV_0000000025
# Processing measure: MALARIA004
# Discarded empty DataFrame for measure: MALARIA004
# Processing measure: anc1
# Processing measure: bcgv
# Discarded empty DataFrame for measure: bcgv
# Processing measure: cpmo
# Discarded empty DataFrame for measure: cpmo
# Processing measure: cpmt
# Processing measure: dptv
# Discarded empty DataFrame for measure: dptv
# Processing measure: ebreast
# Discarded empty DataFrame for measure: ebreast
# Processing measure: ort
# Processing measure: poliov
# Discarded empty DataFrame for measure: poliov
# Processing measure: sba
# Processing measure: vita
# Processing measure: anc15
# Processing measure: anc45
# Processing measure: csection5
# Processing measure: ebreast5
# Discarded empty DataFrame for measure: ebreast5
# Processing measure: pncall3
# Processing measure: pncall5
# Processing measure: pnchome3
# Processing measure: pnchome5
# Processing measure: sba5
# Processing measure: stunt3
# Discarded empty DataFrame for measure: stunt3
# Processing measure: stunt5
# Processing measure: uweight3
# Discarded empty DataFrame for measure: uweight3
# Processing measure: uweight5
# Discarded empty DataFrame for measure: uweight5
# Processing measure: asfr1
# Processing measure: tfr
# Processing measure: imr
# Processing measure: nmr
# Processing measure: u5mr
# Processing measure: SA_0000001697
# Processing measure: SA_0000001698
# Processing measure: SA_0000001699
# Processing measure: SA_0000001700
# Processing measure: SA_0000001701
# Processing measure: SA_0000001702
# Processing measure: SA_0000001703
# Processing measure: SA_0000001704
# Processing measure: SA_0000001705
# Processing measure: SA_0000001706
# Processing measure: SA_0000001707
# Processing measure: SA_0000001708
# Processing measure: SA_0000001709
# Processing measure: SA_0000001710
# Processing measure: SA_0000001711
# Processing measure: SA_0000001712
# Processing measure: SA_0000001713
# Processing measure: SA_0000001714
# Processing measure: SA_0000001715
# Processing measure: SA_0000001716
# Processing measure: SA_0000001717
# Processing measure: MEDS201110200
# Discarded empty DataFrame for measure: MEDS201110200
# Processing measure: MEDS201120200C
# Discarded empty DataFrame for measure: MEDS201120200C
# Processing measure: MEDS2011400C
# Discarded empty DataFrame for measure: MEDS2011400C
# Processing measure: MEDS2011600C
# Discarded empty DataFrame for measure: MEDS2011600C
# Processing measure: MEDS201170200C
# Discarded empty DataFrame for measure: MEDS201170200C
# Processing measure: MEDS2020200C
# Discarded empty DataFrame for measure: MEDS2020200C
# Processing measure: MEDS3010400
# Discarded empty DataFrame for measure: MEDS3010400
# Processing measure: MEDS3010700
# Discarded empty DataFrame for measure: MEDS3010700
# Processing measure: MEDS3011000
# Discarded empty DataFrame for measure: MEDS3011000
# Processing measure: MEDS5010200
# Discarded empty DataFrame for measure: MEDS5010200
# Processing measure: MEDS5010700
# Discarded empty DataFrame for measure: MEDS5010700
# Processing measure: MEDS5020100
# Discarded empty DataFrame for measure: MEDS5020100
# Processing measure: MEDS5021700S
# Discarded empty DataFrame for measure: MEDS5021700S
# Processing measure: MEDS5021800S
# Discarded empty DataFrame for measure: MEDS5021800S
# Processing measure: MEDS5030200
# Discarded empty DataFrame for measure: MEDS5030200
# Processing measure: MEDS5050200
# Discarded empty DataFrame for measure: MEDS5050200
# Processing measure: MEDS5050900
# Discarded empty DataFrame for measure: MEDS5050900
# Processing measure: MEDS5060200
# Discarded empty DataFrame for measure: MEDS5060200
# Processing measure: MEDS5070100
# Discarded empty DataFrame for measure: MEDS5070100
# Processing measure: MEDS5070300
# Discarded empty DataFrame for measure: MEDS5070300
# Processing measure: MEDS5080100
# Discarded empty DataFrame for measure: MEDS5080100
# Processing measure: MEDS5090300
# Discarded empty DataFrame for measure: MEDS5090300
# Processing measure: MEDS5100400
# Discarded empty DataFrame for measure: MEDS5100400
# Processing measure: MEDS6010102
# Discarded empty DataFrame for measure: MEDS6010102
# Processing measure: MEDS6010103
# Discarded empty DataFrame for measure: MEDS6010103
# Processing measure: MEDS6010201
# Discarded empty DataFrame for measure: MEDS6010201
# Processing measure: MEDS6010300
# Discarded empty DataFrame for measure: MEDS6010300
# Processing measure: MEDS6030100
# Discarded empty DataFrame for measure: MEDS6030100
# Processing measure: MEDS6060100
# Discarded empty DataFrame for measure: MEDS6060100
# Processing measure: MEDS6060200
# Discarded empty DataFrame for measure: MEDS6060200
# Processing measure: MEDS6060300
# Discarded empty DataFrame for measure: MEDS6060300
# Processing measure: MEDS7010400
# Discarded empty DataFrame for measure: MEDS7010400
# Processing measure: MEDS7020900S
# Discarded empty DataFrame for measure: MEDS7020900S
# Processing measure: MEDS8010100
# Discarded empty DataFrame for measure: MEDS8010100
# Processing measure: MEDS8010200
# Discarded empty DataFrame for measure: MEDS8010200
# Processing measure: MEDS8010500
# Discarded empty DataFrame for measure: MEDS8010500
# Processing measure: MEDS8010800
# Discarded empty DataFrame for measure: MEDS8010800
# Processing measure: MEDS8011200
# Discarded empty DataFrame for measure: MEDS8011200
# Processing measure: MEDS8021201
# Discarded empty DataFrame for measure: MEDS8021201
# Processing measure: MEDS8021202
# Discarded empty DataFrame for measure: MEDS8021202
# Processing measure: MEDS8030400
# Discarded empty DataFrame for measure: MEDS8030400
# Processing measure: MEDS8030500
# Discarded empty DataFrame for measure: MEDS8030500
# Processing measure: MEDS3011302
# Discarded empty DataFrame for measure: MEDS3011302
# Processing measure: MEDS5020600
# Discarded empty DataFrame for measure: MEDS5020600
# Processing measure: MEDS5100800
# Discarded empty DataFrame for measure: MEDS5100800
# Processing measure: MEDS4020300
# Discarded empty DataFrame for measure: MEDS4020300
# Processing measure: MEDS2012100S
# Discarded empty DataFrame for measure: MEDS2012100S
# Processing measure: NHABASIS
# Processing measure: PerctestedANC
# Processing measure: PercposANC
# Processing measure: PercposSW
# Discarded empty DataFrame for measure: PercposSW
# Processing measure: PercposMSM
# Discarded empty DataFrame for measure: PercposMSM
# Processing measure: HIV_0000000026
# Processing measure: NCDMORT3070
# Processing measure: MALARIA005
# Discarded empty DataFrame for measure: MALARIA005
# Processing measure: WHS_PBR
# Processing measure: MEDS1_01_01
# Discarded empty DataFrame for measure: MEDS1_01_01
# Processing measure: MEDS1_02_01
# Discarded empty DataFrame for measure: MEDS1_02_01
# Processing measure: MEDS1_02_02
# Discarded empty DataFrame for measure: MEDS1_02_02
# Processing measure: MEDS1_02_04
# Discarded empty DataFrame for measure: MEDS1_02_04
# Processing measure: MEDS1_02_03
# Discarded empty DataFrame for measure: MEDS1_02_03
# Processing measure: MEDS1_01_03
# Discarded empty DataFrame for measure: MEDS1_01_03
# Processing measure: MEDS1_01_05
# Discarded empty DataFrame for measure: MEDS1_01_05
# Processing measure: MEDS1_02_11
# Discarded empty DataFrame for measure: MEDS1_02_11
# Processing measure: MEDS1_02_12
# Discarded empty DataFrame for measure: MEDS1_02_12
# Processing measure: MEDS1_02_13
# Discarded empty DataFrame for measure: MEDS1_02_13
# Processing measure: MEDS1_02_15
# Discarded empty DataFrame for measure: MEDS1_02_15
# Processing measure: MEDS1_02_16
# Discarded empty DataFrame for measure: MEDS1_02_16
# Processing measure: MEDS1_02_14
# Discarded empty DataFrame for measure: MEDS1_02_14
# Processing measure: MEDS2_01_01_02
# Discarded empty DataFrame for measure: MEDS2_01_01_02
# Processing measure: MEDS2_01_03_02
# Discarded empty DataFrame for measure: MEDS2_01_03_02
# Processing measure: MEDS2_01_04_02
# Discarded empty DataFrame for measure: MEDS2_01_04_02
# Processing measure: MEDS2_01_07_02
# Discarded empty DataFrame for measure: MEDS2_01_07_02
# Processing measure: MEDS2_01_05
# Discarded empty DataFrame for measure: MEDS2_01_05
# Processing measure: MEDS2_01_06
# Discarded empty DataFrame for measure: MEDS2_01_06
# Processing measure: MEDS2_01_08
# Discarded empty DataFrame for measure: MEDS2_01_08
# Processing measure: MEDS2_01_24
# Discarded empty DataFrame for measure: MEDS2_01_24
# Processing measure: MEDS2_01_26
# Discarded empty DataFrame for measure: MEDS2_01_26
# Processing measure: MEDS2_01_10
# Discarded empty DataFrame for measure: MEDS2_01_10
# Processing measure: MEDS2_01_09
# Discarded empty DataFrame for measure: MEDS2_01_09
# Processing measure: MEDS2_01_11_02
# Discarded empty DataFrame for measure: MEDS2_01_11_02
# Processing measure: MEDS2_01_14
# Discarded empty DataFrame for measure: MEDS2_01_14
# Processing measure: MEDS2_01_13
# Discarded empty DataFrame for measure: MEDS2_01_13
# Processing measure: MEDS2_01_12_02
# Discarded empty DataFrame for measure: MEDS2_01_12_02
# Processing measure: MEDS2_01_15_02
# Discarded empty DataFrame for measure: MEDS2_01_15_02
# Processing measure: MEDS2_01_18_02
# Discarded empty DataFrame for measure: MEDS2_01_18_02
# Processing measure: MEDS2_01_21
# Discarded empty DataFrame for measure: MEDS2_01_21
# Processing measure: MEDS2_02_01
# Discarded empty DataFrame for measure: MEDS2_02_01
# Processing measure: MEDS2_02_02
# Discarded empty DataFrame for measure: MEDS2_02_02
# Processing measure: MEDS3_01_01
# Discarded empty DataFrame for measure: MEDS3_01_01
# Processing measure: MEDS3_01_02
# Discarded empty DataFrame for measure: MEDS3_01_02
# Processing measure: MEDS3_01_04
# Discarded empty DataFrame for measure: MEDS3_01_04
# Processing measure: MEDS3_01_07
# Discarded empty DataFrame for measure: MEDS3_01_07
# Processing measure: MEDS3_01_12_01
# Discarded empty DataFrame for measure: MEDS3_01_12_01
# Processing measure: MEDS3_01_08
# Discarded empty DataFrame for measure: MEDS3_01_08
# Processing measure: MEDS3_01_09
# Discarded empty DataFrame for measure: MEDS3_01_09
# Processing measure: MEDS3_01_10
# Discarded empty DataFrame for measure: MEDS3_01_10
# Processing measure: MEDS3_01_13
# Discarded empty DataFrame for measure: MEDS3_01_13
# Processing measure: MEDS3_01_11
# Discarded empty DataFrame for measure: MEDS3_01_11
# Processing measure: MEDS3_01_14
# Discarded empty DataFrame for measure: MEDS3_01_14
# Processing measure: MEDS3_01_15
# Discarded empty DataFrame for measure: MEDS3_01_15
# Processing measure: MEDS3_01_16
# Discarded empty DataFrame for measure: MEDS3_01_16
# Processing measure: MEDS4_01_02_01
# Discarded empty DataFrame for measure: MEDS4_01_02_01
# Processing measure: MEDS4_01_02_02
# Discarded empty DataFrame for measure: MEDS4_01_02_02
# Processing measure: MEDS4_01_02_03
# Discarded empty DataFrame for measure: MEDS4_01_02_03
# Processing measure: MEDS4_01_02_04
# Discarded empty DataFrame for measure: MEDS4_01_02_04
# Processing measure: MEDS4_01_04
# Discarded empty DataFrame for measure: MEDS4_01_04
# Processing measure: MEDS4_01_06
# Discarded empty DataFrame for measure: MEDS4_01_06
# Processing measure: MEDS4_01_07_01
# Discarded empty DataFrame for measure: MEDS4_01_07_01
# Processing measure: MEDS4_01_07_02
# Discarded empty DataFrame for measure: MEDS4_01_07_02
# Processing measure: MEDS4_01_08
# Discarded empty DataFrame for measure: MEDS4_01_08
# Processing measure: MEDS4_01_10
# Discarded empty DataFrame for measure: MEDS4_01_10
# Processing measure: MEDS4_01_11
# Discarded empty DataFrame for measure: MEDS4_01_11
# Processing measure: MEDS4_01_12
# Discarded empty DataFrame for measure: MEDS4_01_12
# Processing measure: MEDS4_02_01
# Discarded empty DataFrame for measure: MEDS4_02_01
# Processing measure: MEDS4_02_02_01
# Discarded empty DataFrame for measure: MEDS4_02_02_01
# Processing measure: MEDS4_02_02_02
# Discarded empty DataFrame for measure: MEDS4_02_02_02
# Processing measure: MEDS4_02_02_03
# Discarded empty DataFrame for measure: MEDS4_02_02_03
# Processing measure: MEDS4_02_02_04
# Discarded empty DataFrame for measure: MEDS4_02_02_04
# Processing measure: MEDS4_02_03
# Discarded empty DataFrame for measure: MEDS4_02_03
# Processing measure: MEDS4_02_05
# Discarded empty DataFrame for measure: MEDS4_02_05
# Processing measure: MEDS5_01_01
# Discarded empty DataFrame for measure: MEDS5_01_01
# Processing measure: MEDS5_01_02
# Discarded empty DataFrame for measure: MEDS5_01_02
# Processing measure: MEDS5_01_04_01
# Discarded empty DataFrame for measure: MEDS5_01_04_01
# Processing measure: MEDS5_01_04_02
# Discarded empty DataFrame for measure: MEDS5_01_04_02
# Processing measure: MEDS5_01_07
# Discarded empty DataFrame for measure: MEDS5_01_07
# Processing measure: MEDS5_01_08
# Discarded empty DataFrame for measure: MEDS5_01_08
# Processing measure: MEDS5_01_09
# Discarded empty DataFrame for measure: MEDS5_01_09
# Processing measure: MEDS5_01_10
# Discarded empty DataFrame for measure: MEDS5_01_10
# Processing measure: MEDS5_01_15
# Discarded empty DataFrame for measure: MEDS5_01_15
# Processing measure: MEDS5_01_05_01
# Discarded empty DataFrame for measure: MEDS5_01_05_01
# Processing measure: MEDS5_01_05_02
# Discarded empty DataFrame for measure: MEDS5_01_05_02
# Processing measure: MEDS5_01_05_03
# Discarded empty DataFrame for measure: MEDS5_01_05_03
# Processing measure: MEDS5_01_05_04
# Discarded empty DataFrame for measure: MEDS5_01_05_04
# Processing measure: MEDS5_01_05_05
# Discarded empty DataFrame for measure: MEDS5_01_05_05
# Processing measure: MEDS5_01_05_06
# Discarded empty DataFrame for measure: MEDS5_01_05_06
# Processing measure: MEDS5_01_05_07
# Discarded empty DataFrame for measure: MEDS5_01_05_07
# Processing measure: MEDS5_01_05_08
# Discarded empty DataFrame for measure: MEDS5_01_05_08
# Processing measure: MEDS5_01_05_09
# Discarded empty DataFrame for measure: MEDS5_01_05_09
# Processing measure: MEDS5_01_11
# Discarded empty DataFrame for measure: MEDS5_01_11
# Processing measure: MEDS5_01_12
# Discarded empty DataFrame for measure: MEDS5_01_12
# Processing measure: MEDS5_01_13
# Discarded empty DataFrame for measure: MEDS5_01_13
# Processing measure: MEDS5_01_14
# Discarded empty DataFrame for measure: MEDS5_01_14
# Processing measure: MEDS5_02_01
# Discarded empty DataFrame for measure: MEDS5_02_01
# Processing measure: MEDS5_02_02
# Discarded empty DataFrame for measure: MEDS5_02_02
# Processing measure: MEDS5_02_03
# Discarded empty DataFrame for measure: MEDS5_02_03
# Processing measure: MEDS5_02_04
# Discarded empty DataFrame for measure: MEDS5_02_04
# Processing measure: MEDS5_02_05
# Discarded empty DataFrame for measure: MEDS5_02_05
# Processing measure: MEDS5_02_06
# Discarded empty DataFrame for measure: MEDS5_02_06
# Processing measure: MEDS5_02_07
# Discarded empty DataFrame for measure: MEDS5_02_07
# Processing measure: MEDS5_02_08
# Discarded empty DataFrame for measure: MEDS5_02_08
# Processing measure: MEDS5_02_09
# Discarded empty DataFrame for measure: MEDS5_02_09
# Processing measure: MEDS5_02_17
# Discarded empty DataFrame for measure: MEDS5_02_17
# Processing measure: MEDS5_02_18
# Discarded empty DataFrame for measure: MEDS5_02_18
# Processing measure: MEDS5_03_01
# Discarded empty DataFrame for measure: MEDS5_03_01
# Processing measure: MEDS5_03_02
# Discarded empty DataFrame for measure: MEDS5_03_02
# Processing measure: MEDS5_03_03_01
# Discarded empty DataFrame for measure: MEDS5_03_03_01
# Processing measure: MEDS5_03_03_02
# Discarded empty DataFrame for measure: MEDS5_03_03_02
# Processing measure: MEDS5_03_04
# Discarded empty DataFrame for measure: MEDS5_03_04
# Processing measure: MEDS5_03_05_01
# Discarded empty DataFrame for measure: MEDS5_03_05_01
# Processing measure: MEDS5_03_05_02
# Discarded empty DataFrame for measure: MEDS5_03_05_02
# Processing measure: MEDS5_03_05_03
# Discarded empty DataFrame for measure: MEDS5_03_05_03
# Processing measure: MEDS5_03_05_04
# Discarded empty DataFrame for measure: MEDS5_03_05_04
# Processing measure: MEDS5_03_05_05
# Discarded empty DataFrame for measure: MEDS5_03_05_05
# Processing measure: MEDS5_04_01
# Discarded empty DataFrame for measure: MEDS5_04_01
# Processing measure: MEDS5_04_02
# Discarded empty DataFrame for measure: MEDS5_04_02
# Processing measure: MEDS5_04_03
# Discarded empty DataFrame for measure: MEDS5_04_03
# Processing measure: MEDS5_04_04
# ...
# Processing measure: FOODBORNE_YLD_LT5
# Discarded empty DataFrame for measure: FOODBORNE_YLD_LT5
# Processing measure: FOODBORNE_YLL_LT5
# Discarded empty DataFrame for measure: FOODBORNE_YLL_LT5
# Processing measure: FOODBORNE_DALY_LT5
# Discarded empty DataFrame for measure: FOODBORNE_DALY_LT5
# Processing measure: FOODBORNE_ILL_100K_LT5
# Discarded empty DataFrame for measure: FOODBORNE_ILL_100K_LT5
# Processing measure: FOODBORNE_DTH_100K_LT5
# Discarded empty DataFrame for measure: FOODBORNE_DTH_100K_LT5
# Processing measure: FOODBORNE_YLD_100K_LT5
# Discarded empty DataFrame for measure: FOODBORNE_YLD_100K_LT5
# Processing measure: FOODBORNE_YLL_100K_LT5
# Discarded empty DataFrame for measure: FOODBORNE_YLL_100K_LT5
# Processing measure: FOODBORNE_DALY_100k_LT5
# Discarded empty DataFrame for measure: FOODBORNE_DALY_100k_LT5
# Processing measure: FOODBORNE_YLD_CASE_LT5
# Discarded empty DataFrame for measure: FOODBORNE_YLD_CASE_LT5
# Processing measure: FOODBORNE_YLL_CASE_LT5
# Discarded empty DataFrame for measure: FOODBORNE_YLL_CASE_LT5
# Processing measure: FOODBORNE_DALY_CASE_LT5
# Discarded empty DataFrame for measure: FOODBORNE_DALY_CASE_LT5
# Processing measure: HAZARD_ILL_TOTAL
# Discarded empty DataFrame for measure: HAZARD_ILL_TOTAL
# Processing measure: HAZARD_DTH_TOTAL
# Discarded empty DataFrame for measure: HAZARD_DTH_TOTAL
# Processing measure: HAZARD_YLD_TOTAL
# Discarded empty DataFrame for measure: HAZARD_YLD_TOTAL
# Processing measure: HAZARD_YLL_TOTAL
# Discarded empty DataFrame for measure: HAZARD_YLL_TOTAL
# Processing measure: HAZARD_DALY_TOTAL
# Discarded empty DataFrame for measure: HAZARD_DALY_TOTAL
# Processing measure: HAZARD_ILL_GE5
# Discarded empty DataFrame for measure: HAZARD_ILL_GE5
# Processing measure: HAZARD_DTH_GE5
# Discarded empty DataFrame for measure: HAZARD_DTH_GE5
# Processing measure: HAZARD_YLD_GE5
# Discarded empty DataFrame for measure: HAZARD_YLD_GE5
# Processing measure: HAZARD_YLL_GE5
# Discarded empty DataFrame for measure: HAZARD_YLL_GE5
# Processing measure: HAZARD_DALY_GE5
# Discarded empty DataFrame for measure: HAZARD_DALY_GE5
# Processing measure: HAZARD_ILL_LT5
# Discarded empty DataFrame for measure: HAZARD_ILL_LT5
# Processing measure: HAZARD_DTH_LT5
# Discarded empty DataFrame for measure: HAZARD_DTH_LT5
# Processing measure: HAZARD_YLD_LT5
# Discarded empty DataFrame for measure: HAZARD_YLD_LT5
# Processing measure: HAZARD_YLL_LT5
# Discarded empty DataFrame for measure: HAZARD_YLL_LT5
# Processing measure: HAZARD_DALY_LT5
# Discarded empty DataFrame for measure: HAZARD_DALY_LT5
# Processing measure: NCD_CCS_FOOD_TAX
# Processing measure: NCD_CCS_PRICE_SUBS
# Processing measure: NCD_CCS_PA_TAX
# Processing measure: NCD_CCS_EyePlan
# Processing measure: NCD_CCS_HearingPlan
# Processing measure: NCD_CCS_OvwtPlan
# Processing measure: NCD_CCS_PA_GUIDELINES
# Processing measure: NCD_CCS_PA_MASS_PART
# Processing measure: NCD_CCS_DIET_AWARE
# Processing measure: NCD_CCS_MORT_TARGET
# Processing measure: NCD_CCS_ALC_TARGET
# Processing measure: NCD_CCS_PA_TARGET
# Processing measure: NCD_CCS_SALT_TARGET
# Processing measure: NCD_CCS_TOB_TARGET
# Processing measure: NCD_CCS_BP_TARGET
# Processing measure: NCD_CCS_DIAB_TARGET
# Processing measure: NCD_CCS_OBES_TARGET
# Processing measure: NCD_CCS_DRUG_THERAPY_TARGET
# Processing measure: NCD_CCS_ESS_MEDS_TECH_TARGET
# Processing measure: NCD_CCS_PBCR
# Processing measure: NCD_CCS_ALC_SVY
# Processing measure: NCD_CCS_TOB_SVY
# Processing measure: NCD_CCS_DIET_SVY
# Processing measure: NCD_CCS_PA_SVY
# Processing measure: NCD_CCS_DIAB_SVY
# Processing measure: NCD_CCS_CHOL_SVY
# Processing measure: NCD_CCS_BP_SVY
# Processing measure: NCD_CCS_SALT_SVY
# Processing measure: NCD_CCS_OVWT_SVY
# Processing measure: NCD_CCS_dilated_fundus
# Processing measure: NCD_CCS_foot_vibr
# Processing measure: NCD_CCS_urine_strips_gluc_ketone
# Processing measure: NCD_CCS_BPmsmt
# Processing measure: NCD_CCS_PeakFlow
# Processing measure: NCD_CCS_LIS_AML_COMBO
# Processing measure: NCD_CCS_LIS_HYDRO_COMBO
# Processing measure: NCD_CCS_TEL_AML_COMBO
# Processing measure: NCD_CCS_TEL_HYDRO_COMBO
# Processing measure: NCD_CCS_ComboInhaler
# Processing measure: NCD_CCS_diab_retin
# Processing measure: NCD_CCS_alteplase
# Processing measure: NCD_CCS_CVD_GUIDE
# Processing measure: NCD_CCS_DIAB_GUIDE
# Processing measure: NCD_CCS_CANCER_GUIDE
# Processing measure: NCD_CCS_CRD_GUIDE
# Processing measure: NCD_CCS_ALC_MGMT_GUIDE
# Processing measure: NCD_CCS_TOB_MGMT_GUIDE
# Processing measure: NCD_CCS_OBES_MGMT_GUIDE
# Processing measure: NCD_CCS_PA_MGMT_GUIDE
# Processing measure: NCD_CCS_CANCER_DEPT
# Processing measure: NCD_CCS_path_lab
# Processing measure: NCD_CCS_cancer_surgery
# Processing measure: NCD_CCS_chemo
# Processing measure: NCD_CCS_radio
# Processing measure: WSH_DOMESTIC_WASTE_SAFELY_TREATED
# Processing measure: AMR_INFECT_ECOLI
# Processing measure: AMR_INFECT_MRSA
# Processing measure: SDGIHR2021
# Processing measure: vzdpt
# Processing measure: NCD_CCS_PA_GUIDELINES_UNDER5
# Processing measure: NCD_CCS_PA_GUIDELINES_ADULTS
# Processing measure: NCD_CCS_PA_GUIDELINES_5to19
# Processing measure: NCD_CCS_PA_GUIDELINES_OLDADULTS
# Processing measure: NCD_CCS_PA_POL_WALKBIKE
# Processing measure: NCD_CCS_PA_POL_WORK
# Processing measure: NCD_CCS_PA_POL_AGEING
# Processing measure: NCD_CCS_PA_POL_COMM_BASED
# Processing measure: NCD_CCS_PA_POL_PUBLIC
# Processing measure: NCD_CCS_PA_POL_CHILDCARE
# Processing measure: NUTRITION_ANT_HAZ_NE2
# Failed to retrieve data for measure: NUTRITION_ANT_HAZ_NE2 with status code: 502
# Processing measure: NUTRITION_ANT_WHZ_NE2
# Failed to retrieve data for measure: NUTRITION_ANT_WHZ_NE2 with status code: 502
# Processing measure: AIR_46
# Processing measure: AIR_71
# Processing measure: AIR_72
# Processing measure: AIR_73
# Processing measure: AIR_74
# Processing measure: AIR_75
# Processing measure: NCD_CXCA_SCREENED_WITHIN_TIMEPERIOD
# Processing measure: GLASSAMC_TC
# Processing measure: GLASSAMC_AWARE
# Processing measure: GLASSAMC_GPW13_T4B
# Processing measure: HCF_NO_ELECTRICITY
# Processing measure: HCF_REL_ELECTRICITY
# Processing measure: DEVICES24
# Processing measure: DEVICES25
# Processing measure: PRISON_A1_CAPACITY
# Processing measure: PRISON_A2_PRISIONERS_N
# Processing measure: PRISON_A2_PRISIONERS_PER100KPOP
# Processing measure: PRISON_A4_NEWPRISONERS_PER100KPOP
# Processing measure: PRISON_B3_DELIVHEALTHCARE
# Processing measure: PRISON_B9_STAFF_RATIO
# Processing measure: PRISON_B9_1_PHYSICIANS_RATIO
# Processing measure: PRISON_B9_1_NURSES_RATIO
# Processing measure: PRISON_B9_1_PHYCHIATRISTS_RATIO
# Processing measure: PRISON_B9_1_DENTISTS_RATIO
# Processing measure: PRISON_B11_VACPREV_DTP
# Processing measure: PRISON_B11_VACPREV_HPV
# Processing measure: PRISON_B11_VACPREV_HEPA
# Processing measure: PRISON_B11_VACPREV_HEPB
# Processing measure: PRISON_B11_VACPREV_FLU
# Processing measure: PRISON_B11_VACPREV_MMR
# Processing measure: PRISON_B13_ASSESSMENTS
# Processing measure: PRISON_B14_ERRORS
# Processing measure: PRISON_B15_REPDRUGEVENTS
# Processing measure: PRISON_B16_SUICIDERISK
# Processing measure: PRISON_B17_INVOLVEMENT
# Processing measure: PRISON_B20_CLINICALREP
# Processing measure: PRISON_C8_CONDOMS
# Processing measure: PRISON_C8_NEEDLES
# Processing measure: PRISON_C16_LABTESTS
# Processing measure: PRISON_D3_DEATHS_TOT
# Processing measure: PRISON_D3_DEATHS_SUICIDE_MRATE
# Processing measure: PRISON_D3_DEATHS_DRUG_MRATE
# Processing measure: PRISON_D3_DEATHS_COVID_MRATE
# Processing measure: PRISON_D4_TB_DIAG_TOT
# Processing measure: PRISON_D4_MDRTB_DIAG_TOT
# Processing measure: PRISON_D4_HIV_DIAG_TOT
# Processing measure: PRISON_D4_HEPC_DIAG_TOT
# Processing measure: PRISON_D4_HEPB_DIAG_TOT
# Processing measure: PRISON_D4_STI_DIAG_TOT
# Processing measure: PRISON_D4_COVID_TOT
# Processing measure: PRISON_D4_MH_DIAG_TOT
# Processing measure: PRISON_D4_SUD_DIAG_TOT
# Processing measure: PRISON_D4_DIABETES_DIAG_TOT
# Processing measure: PRISON_D4_CARDIOVASC_DIAG_TOT
# Processing measure: PRISON_D4_CANCER_DIAG_TOT
# Processing measure: PRISON_F1_BMI25_TOT
# Processing measure: PRISON_F1_BMI30_TOT
# Processing measure: PRISON_F1_TOBACCO_TOT
# Processing measure: PRISON_F1_ALCOHOL_TOT
# Processing measure: PRISON_F1_DRUGUSERS_TOT
# Processing measure: PRISON_F1_INJECTDRUGUSERS_TOT
# Processing measure: PRISON_F1_EXERCISE_TOT
# Processing measure: CCH_SURVEY_MOH_FOCALPOINT
# Processing measure: CCH_SURVEY_MULTISTAKEHOLDER_MECHANISM_EXISTS
# Processing measure: CCH_SURVEY_AGREEMENT_MOH_OTHERSECTORS
# Processing measure: CCH_SURVEY_VULNERABILITY_ADAPTATION_ASSESSMENT
# Processing measure: CCH_SURVEY_PLAN_STRATEGY_DEVELOPED
# Processing measure: CCH_SURVEY_SURVEILLANCE_SYSTEM_EXISTS
# Processing measure: CCH_SURVEY_SURVEILLANCE_WHICH_METEOROLOGICAL
# Processing measure: HCF_UNREL_ELECTRICITY
# Processing measure: CHILDMORT10TO19
# Failed to retrieve data for measure: CHILDMORT10TO19 with status code: 502
# Processing measure: ORALHEALTH_UNTREATEDCARIESDECIDUOUS
# Processing measure: ORALHEALTH_UNTREATEDCARIESPERMANENT
# Processing measure: ORALHEALTH_SEVEREPERIODONTALDISEASE
# Processing measure: ORALHEALTH_EDENTULISM_PREVALENCE
# Processing measure: ORALHEALTH_EDENTULISM_NEWCASES
# Discarded empty DataFrame for measure: ORALHEALTH_EDENTULISM_NEWCASES
# Processing measure: ORALHEALTH_EDENTULISM_INCIDENCE100K
# Discarded empty DataFrame for measure: ORALHEALTH_EDENTULISM_INCIDENCE100K
# Processing measure: ORALHEALTH_CAVITY_SUGAR
# Discarded empty DataFrame for measure: ORALHEALTH_CAVITY_SUGAR
# Processing measure: ORALHEALTH_DENTALHEALTHCARE_EXP_TOTAL
# Processing measure: ORALHEALTH_DENTALHEALTHCARE_EXP_PERCAP
# Processing measure: ORALHEALTH_PRODLOSS_ORALDISEASES
# Processing measure: ORALHEALTH_AFFORDABILITY_FLUORIDETOOTHPASTE
# Processing measure: ORALHEALTH_NCD_STAFF
# Processing measure: ORALHEALTH_NOMA
# Processing measure: ORALHEALTH_WORKFORCE_PROSTHETIC
# Discarded empty DataFrame for measure: ORALHEALTH_WORKFORCE_PROSTHETIC
# Processing measure: ORALHEALTH_AVAILABILITY_SCREENING
# Processing measure: ORALHEALTH_AVAILABILITY_URGENTCARE
# Processing measure: ORALHEALTH_AVAILABILITY_RESTORATIVE
# Processing measure: ORALHEALTH_UHC_GOVSCHEME
# Processing measure: ORALHEALTH_UHC_PREVENTIVE
# Processing measure: ORALHEALTH_UHC_ESSENTIAL_CURATIVE
# Processing measure: ORALHEALTH_UHC_ADVANCE_CURATIVE
# Processing measure: ORALHEALTH_UHC_REHABILITATION
# Processing measure: FINPROTECTION_IMP_P_215_LEVEL_MILLION
# Processing measure: FINPROTECTION_IMP_P_215_LEVEL_SH
# Processing measure: FINPROTECTION_IMP_NP_215_LEVEL_MILLION
# Processing measure: FINPROTECTION_IMP_NP_215_LEVEL_SH
# Processing measure: FINPROTECTION_IMP_P_365_LEVEL_MILLION
# Processing measure: FINPROTECTION_IMP_P_365_LEVEL_SH
# Processing measure: FINPROTECTION_IMP_NP_365_LEVEL_MILLION
# Processing measure: FINPROTECTION_IMP_NP_365_LEVEL_SH
# Processing measure: FINPROTECTION_IMP_P215_POP
# Processing measure: FINPROTECTION_IMP_NP215_POP
# Processing measure: FINPROTECTION_IMP_PG_215_STD
# Processing measure: FINPROTECTION_IMP_P365_POP
# Processing measure: FINPROTECTION_IMP_NP365_POP
# Processing measure: FINPROTECTION_IMP_PG_365_STD
# Processing measure: ORAL_HEALTH_CANCER_LIPORALCAVITY_NEWCASE_NUMBER
# Processing measure: ORAL_HEALTH_CANCER_LIPORALCAVITY_100K
# Processing measure: ORALHEALTH_SUGAR_AVAILABILITY
# Processing measure: ORALHEALTH_HWF_DENTALPROSTHETICTECH_10K
# Processing measure: ORALHEALTH_FLUORIDETOOTHPHASTE_LABOURDAYS
# Processing measure: ORALHEALTH_DENOMINATOR_TTLPOP
# Processing measure: ORALHEALTH_DENOMINATOR_CHEPPP
# Processing measure: SRH_PREGNANCY_UNINTENDED_RATE
# Processing measure: SRH_ABORTION_RATE
# Processing measure: HEPB_HBSAG_CARRIER
# Discarded empty DataFrame for measure: HEPB_HBSAG_CARRIER
# Processing measure: PRETERMBIRTH_RATE
# Processing measure: PRETERMBIRTH_NUMBER
# Processing measure: STI_SYPHILIS_PREVALENTCASES
# Processing measure: STI_SYPHILIS_PREVALENCE_PER100
# Processing measure: STI_SYPHILIS_INCIDENTCASES
# Processing measure: STI_SYPHILIS_INCIDENCE_PER1000
# Processing measure: STI_CHLAMYDIA_PREVALENTCASES
# Processing measure: STI_CHLAMYDIA_PREVALENCE_PER100
# Processing measure: STI_CHLAMYDIA_INCIDENTCASES
# Processing measure: STI_CHLAMYDIA_INCIDENCE_PER1000
# Processing measure: STI_GONORRHOEA_PREVALENTCASES
# Processing measure: STI_GONORRHOEA_PREVALENCE_PER100
# Processing measure: STI_GONORRHOEA_INCIDENTCASES
# Processing measure: STI_GONORRHOEA_INCIDENCE_PER1000
# Processing measure: STI_TRICHOMONIASIS_PREVALENTCASES
# Processing measure: STI_TRICHOMONIASIS_PREVALENCE_PER100
# Processing measure: STI_TRICHOMONIASIS_INCIDENTCASES
# Processing measure: STI_TRICHOMONIASIS_INCIDENCE_PER1000
# Processing measure: NUT_BF_CBF
# Processing measure: NUT_BF_EBF
# Processing measure: NUT_BF_EBF2D
# Processing measure: NUT_BF_EIBF
# Processing measure: NUT_BF_EVBF
# Processing measure: NUT_CF_EFF
# Processing measure: NUT_CF_ISSSF
# Processing measure: NUT_CF_MAD
# Processing measure: NUT_CF_MDD
# Processing measure: NUT_CF_MMF
# Processing measure: NUT_CF_ZVF
# Processing measure: TAXBEV_EARMARKEDEXCISETAX
# Processing measure: TAXBEV_PRICE
# Processing measure: TAXBEV_ALCOHOLSALESTATUS
# Processing measure: TAXBEV_ABV
# Processing measure: TAXBEV_SUGARCONTENT
# Processing measure: TAXBEV_MOSTSOLDSPIRIT
# Processing measure: TAXBEV_EXCISE
# Processing measure: TAXBEV_VATSALES
# Processing measure: TAXBEV_IMPORTDUTIES
# Processing measure: TAXBEV_OTHERTAXES
# Processing measure: TAXBEV_TOTALTAXES
# Processing measure: TAXBEV_EXCISE_APPLIED_YN
# Processing measure: TAXBEV_EXCISE_TYPE
# Processing measure: TAXBEV_EXCISE_UNIFORMTIERED
# Discarded empty DataFrame for measure: TAXBEV_EXCISE_UNIFORMTIERED
# Processing measure: TAXBEV_ALCOHOLBASEDTIERED
# Processing measure: TAXBEV_ADVALOREMBASE_ALCOHOLIC
# Discarded empty DataFrame for measure: TAXBEV_ADVALOREMBASE_ALCOHOLIC
# Processing measure: TAXBEV_EXCISE_AUTOADJUST
# Processing measure: TAXBEV_SUGARBASEDTIERED
# Processing measure: TAXBEV_ADVALOREMBASE_NONALCOHOLIC
# Discarded empty DataFrame for measure: TAXBEV_ADVALOREMBASE_NONALCOHOLIC
# Processing measure: NUT_BF_EBF_NUMTH
# Processing measure: TAXBEV_ADVALOREMBASE
# Processing measure: TAXBEV_EXCISE_UNIFORMTIERED_ALCOHOLIC
# Processing measure: TAXBEV_EXCISE_UNIFORMTIERED_NONALCOHOLIC
# Processing measure: NUTRITION_WH_2_NUM
# Processing measure: TOB_R_PRICE
# Processing measure: R_Sp_excise
# Processing measure: R_Ad_val
# Processing measure: R_VAT
# Processing measure: R_Imp_duty
# Processing measure: R_tax_other
# Processing measure: R_Total_tax
# Processing measure: Rev_import
# Processing measure: Rev_other
# Processing measure: R_afford_price_gap_decreased
# Processing measure: R_admin_overt_marking
# Processing measure: R_admin_covert_marking
# Processing measure: R_admin_unique_identifier
# Processing measure: R_admin_identifier_track_and_trace
# Processing measure: R_afford_trend_growth_rate
# Discarded empty DataFrame for measure: R_afford_trend_growth_rate
# Processing measure: R_afford_cat_2
# Processing measure: R_afford_inflation_adjusted_price_lcu
# Processing measure: R_afford_inflation_adjusted_price_ppp
# Processing measure: R_contains_nicotine
# Processing measure: O_mCessation
# Discarded empty DataFrame for measure: O_mCessation
# Processing measure: R_type_variant
# Processing measure: M1_adult_recent
# Processing measure: M2_adult_representative
# Processing measure: M3_adult_periodic
# Processing measure: M4_youth_recent
# Processing measure: M5_youth_representative
# Processing measure: M6_youth_periodic
#               GHO PUBLISHSTATE  YEAR REGION COUNTRY        Display Value  \
# 0  MDG_0000000001    PUBLISHED  2000    AFR     NaN  90.84 [89.31-92.62]
# 1  MDG_0000000001    PUBLISHED  2001    AFR     NaN  87.98 [86.49-89.72]
# 2  MDG_0000000001    PUBLISHED  2002    AFR     NaN  85.05 [83.58-86.74]
# 3  MDG_0000000001    PUBLISHED  2003    AFR     NaN  82.02 [80.56-83.68]
# 4  MDG_0000000001    PUBLISHED  2017    AFR     NaN  54.12 [51.03-58.43]
#
#     Numeric       Low      High  StdErr  StdDev Comments attribute value
# 0  90.83788  89.30656  92.61595     NaN     NaN      NaN       SEX  BTSX
# 1  87.97622  86.49111  89.72169     NaN     NaN      NaN       SEX  BTSX
# 2  85.04704  83.58373  86.74262     NaN     NaN      NaN       SEX  BTSX
# 3  82.01636  80.56035  83.67830     NaN     NaN      NaN       SEX  BTSX
# 4  54.11607  51.02641  58.42746     NaN     NaN      NaN       SEX  BTSX

# %%
final_df
# Out:
#                      GHO PUBLISHSTATE  YEAR REGION COUNTRY  \
# 0         MDG_0000000001    PUBLISHED  2000    AFR     NaN
# 1         MDG_0000000001    PUBLISHED  2001    AFR     NaN
# 2         MDG_0000000001    PUBLISHED  2002    AFR     NaN
# 3         MDG_0000000001    PUBLISHED  2003    AFR     NaN
# 4         MDG_0000000001    PUBLISHED  2017    AFR     NaN
# ...                  ...          ...   ...    ...     ...
# 10917363  R_type_variant    PUBLISHED  2022    WPR     SLB
# 10917364  R_type_variant    PUBLISHED  2022    WPR     TON
# 10917365  R_type_variant    PUBLISHED  2022    WPR     TUV
# 10917366  R_type_variant    PUBLISHED  2022    WPR     VUT
# 10917367  R_type_variant    PUBLISHED  2022    WPR     VNM
#
#                 Display Value   Numeric       Low      High  StdErr  StdDev  \
# 0         90.84 [89.31-92.62]  90.83788  89.30656  92.61595     NaN     NaN
# 1         87.98 [86.49-89.72]  87.97622  86.49111  89.72169     NaN     NaN
# 2         85.05 [83.58-86.74]  85.04704  83.58373  86.74262     NaN     NaN
# 3         82.02 [80.56-83.68]  82.01636  80.56035  83.67830     NaN     NaN
# 4         54.12 [51.03-58.43]  54.11607  51.02641  58.42746     NaN     NaN
# ...                       ...       ...       ...       ...     ...     ...
# 10917363                  NaN       NaN       NaN       NaN     NaN     NaN
# 10917364                  NaN       NaN       NaN       NaN     NaN     NaN
# 10917365                  NaN       NaN       NaN       NaN     NaN     NaN
# 10917366                  NaN       NaN       NaN       NaN     NaN     NaN
# 10917367                  NaN       NaN       NaN       NaN     NaN     NaN
#
#          Comments                 attribute                       value
# 0             NaN                       SEX                        BTSX
# 1             NaN                       SEX                        BTSX
# 2             NaN                       SEX                        BTSX
# 3             NaN                       SEX                        BTSX
# 4             NaN                       SEX                        BTSX
# ...           ...                       ...                         ...
# 10917363      NaN  TOBACCO_NICOTINE_PRODUCT  TOBACCO_SMOKELESS_MOSTSOLD
# 10917364      NaN  TOBACCO_NICOTINE_PRODUCT  TOBACCO_SMOKELESS_MOSTSOLD
# 10917365      NaN  TOBACCO_NICOTINE_PRODUCT  TOBACCO_SMOKELESS_MOSTSOLD
# 10917366      NaN  TOBACCO_NICOTINE_PRODUCT  TOBACCO_SMOKELESS_MOSTSOLD
# 10917367      NaN  TOBACCO_NICOTINE_PRODUCT  TOBACCO_SMOKELESS_MOSTSOLD
#
# [10917368 rows x 14 columns]

# %%
final_df.to_csv('/content/drive/MyDrive/HealthData.csv')
